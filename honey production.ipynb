# %% [markdown]
# ### 1. Import required libraries and read the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\sudee\Downloads\honeyproduction.csv")

# %% [markdown]
# ### 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
df.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
year_distribution=df.year.value_counts()
year_distribution
# Out:
# 2001    44
# 2002    44
# 2003    44
# 1998    43
# 1999    43
# 2000    43
# 2004    41
# 2005    41
# 2006    41
# 2007    41
# 2008    41
# 2009    40
# 2010    40
# 2011    40
# 2012    40
# Name: year, dtype: int64

# %%
year_distribution.plot.pie(autopct="%.f%%")
# Out:
# <Axes: ylabel='year'>

# %% [markdown]
# ### 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.distplot(df["priceperlb"])
# Out:
# C:\Users\sudee\AppData\Local\Temp\ipykernel_1372\1787799046.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["priceperlb"])
# <Axes: xlabel='priceperlb', ylabel='Density'>

# %% [markdown]
# ### 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
plt.scatter(df['numcol'],df['prodvalue'])

# %% [markdown]
# From the above scatter plot between "numcol" and "prodvalue" variable we can see that there is a positive linear relationship between the variables i.e if one variable increases the other one also increases and viceversa

# %% [markdown]
# ### 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(15,15))
df.boxplot(column="prodvalue",by='year')
# Out:
# <Axes: title={'center': 'prodvalue'}, xlabel='year'>

# %% [markdown]
# The above boxplot gives the idea about the outliers in "prodvalue" column according to different years. from that we can say that in the year 2010 has more outlier density

# %% [markdown]
# ### 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(df)

# %% [markdown]
# According to the above pairplot we can get the information regarding the distribution of data w.r.t year variable.
#
# - from the plot between year and numcol variable we can see that in all the year the data of numcol are more distributed in the range of 0-200000
# - from the plot between year and yieldpercol variable we can see that in all the year the data of yieldpercol are more distributed in the range of 50-100
# - from the plot between year and totalprod variable we can see that in all the year the data of totalprod are more distributed in the range of 0-2
# - from the plot between year and stocks variable we can see that in all the year the data of stocks are more distributed in the range of 0-0.5
# - from the plot between year and prodvalue variable we can see that in all the year the data of prodvalue are more distributed in the range of 0-2
# - from the plot between year and priceperlb variable we can see that in the distibution of priceperlb data is not having a same pattern in all the years and it changes according to differnt years

# %% [markdown]
# ### 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\sudee\AppData\Local\Temp\ipykernel_1372\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
u=df.drop('year',axis=1)

# %%
sns.heatmap(u.corr(),annot=True)
# Out:
# C:\Users\sudee\AppData\Local\Temp\ipykernel_1372\3466141772.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(u.corr(),annot=True)
# <Axes: >

# %% [markdown]
# From the above heatmap we can see the variables which are having high correlation and according to the plot we can see that "numcol"-"totalprod", "numcol"-"prodvalue","totalprod"-"prodvalue","stocks"-"numcol","stoks"-"totalprod" are some of the pairs having high positive correlation among them i.e if one variable increases the other also increases and viceversa
